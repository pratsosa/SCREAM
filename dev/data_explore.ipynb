# %%
import numpy as np
from astropy.table import Table
import matplotlib.pyplot as plt
import pandas as pd

# %%
t = Table.read('/pscratch/sd/p/pratsosa/GD-1_gaia_x_decals_040726.fits')

# %%
t.colnames
# Out:
# ['source_id',
#  'ra',
#  'dec',
#  'ra_error',
#  'dec_error',
#  'parallax',
#  'parallax_error',
#  'pmra',
#  'pmra_error',
#  'pmdec',
#  'pmdec_error',
#  'phot_g_mean_flux',
#  'phot_g_mean_flux_error',
#  'phot_g_mean_mag',
#  'phot_bp_mean_flux',
#  'phot_bp_mean_flux_error',
#  'phot_bp_mean_mag',
#  'phot_rp_mean_flux',
#  'phot_rp_mean_flux_error',
#  'phot_rp_mean_mag',
#  'bp_rp',
#  'radial_velocity',
#  'radial_velocity_error',
#  'l',
#  'b',
#  'ls_release',
#  'ls_brickid',
#  'ls_objid',
#  'ls_ra',
#  'ls_dec',
#  'ls_ebv',
#  'ls_flux_g',
#  'ls_flux_r',
#  'ls_flux_z',
#  'ls_flux_ivar_g',
#  'ls_flux_ivar_r',
#  'ls_flux_ivar_z',
#  'ls_mw_transmission_g',
#  'ls_mw_transmission_r',
#  'ls_mw_transmission_z',
#  'match_dist_arcsec',
#  'flux_err_g',
#  'flux_err_r',
#  'flux_err_z',
#  'gmag',
#  'rmag',
#  'zmag',
#  'gmag0',
#  'rmag0',
#  'zmag0',
#  'stream',
#  'phi1',
#  'phi2',
#  'pm_phi1',
#  'pm_phi2',
#  'signal_region']
